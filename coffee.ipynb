# %%
import pandas as pd
df=pd.read_csv("/content/coffee.csv",on_bad_lines='skip')

# %%
df.columns
# Out:
# Index(['Customer_Name', ' Visit_Date', ' Items_Purchased', ' Total_Spent',
#        ' Payment_Method'],
#       dtype='object')

# %%
df
# Out:
#     Customer_Name   Visit_Date  Items_Purchased   Total_Spent  Payment_Method
# 0   Alice Johnson   2025-01-01         Espresso          4.50     Credit Card
# 1       Bob Smith   2025-01-02            Latte          5.00            Cash
# 2   Charlie Brown   2025-01-02       Cappuccino          4.75      Debit Card
# 3       David Lee   2025-01-03        Americano          3.25     Credit Card
# 4       Eva Green   2025-01-03            Mocha          5.50            Cash
# 5      Grace Wong   2025-01-04       Cappuccino          4.75     Credit Card
# 6   Hannah Turner   2025-01-05      Iced Coffee          4.00            Cash
# 7       Ian Black   2025-01-05    Hot Chocolate          3.75      Debit Card
# 8      Jackie Kim   2025-01-06         Espresso          4.50     Credit Card
# 9       Mona Hill   2025-01-07            Mocha          5.50      Debit Card
# 10     Noah Adams   2025-01-07      Iced Coffee          4.00     Credit Card
# ...

# %%
df.drop(columns=' Visit_Date')
# Out:
#     Customer_Name  Items_Purchased   Total_Spent  Payment_Method
# 0   Alice Johnson         Espresso          4.50     Credit Card
# 1       Bob Smith            Latte          5.00            Cash
# 2   Charlie Brown       Cappuccino          4.75      Debit Card
# 3       David Lee        Americano          3.25     Credit Card
# 4       Eva Green            Mocha          5.50            Cash
# 5      Grace Wong       Cappuccino          4.75     Credit Card
# 6   Hannah Turner      Iced Coffee          4.00            Cash
# 7       Ian Black    Hot Chocolate          3.75      Debit Card
# 8      Jackie Kim         Espresso          4.50     Credit Card
# 9       Mona Hill            Mocha          5.50      Debit Card
# 10     Noah Adams      Iced Coffee          4.00     Credit Card
# 11   Olivia Moore       Cappuccino          4.75            Cash
# 12    Peter Brown        Americano          3.25      Debit Card
# ...
